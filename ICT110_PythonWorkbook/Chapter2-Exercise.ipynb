# %% [markdown]
# **Exercise 1**

# %%
name = input('Enter your name: ')
print('Hello', name)
# Out:
# Enter your name: Marc
# Hello Marc

# %% [markdown]
# **Exercise 2**

# %%
pay = float(input("Enter Hours "))
rate = float(input("Enter Rate: "))
payout = pay * rate
print('pay:', payout)
# Out:
# Enter Hours 35
# Enter Rate: 2.75
# pay: 96.25

# %% [markdown]
# **Exercise 3**

# %%
width = 17
height = 12.0

x1 = width//2
x2 = width/2.0
x3 = height/3
x4 = 1 + 2 * 5

print('a: ',x1,type(x1))
print('b: ',x2,type(x2))
print('c: ',x3,type(x3))
print('d: ',x4,type(x4))
# Out:
# a:  8 <class 'int'>
# b:  8.5 <class 'float'>
# c:  4.0 <class 'float'>
# d:  11 <class 'int'>

# %% [markdown]
# **Exercise 4**

# %%
number = int(input('Enter a number: '))
squared = number*number
print(squared)
# Out:
# Enter a number: 9
# 81

# %% [markdown]
# **Challenge**

# %%
number = float(input('Enter a Celcius: '))
F = (number * 9/5) + 32
print('Fahrenheit is :',F)
# Out:
# Enter a Celcius: 36
# Fahrenheit is : 96.8
