# %% [markdown]
# **Exercise 1**

# %%
print('Hello world!')

#Print('Hello world!')
# The error in this is the capital letter P in print
# Out:
# Hello world!

# %%
print ('Hello world!')

#print'Hello world!')
# This code doesnt have parenthesis
# Out:
# Hello world!

# %%
print('Hello world!')

#print('Hello world!)
#This code lacks apostrophe
# Out:
# Hello world!

# %%
print('Hello world!')

#print('Hello world!'')
#This code have double apostrophe in the end
# Out:
# Hello world!

# %% [markdown]
# **Exercise 2**

# %%
x = 43
x = x + 1
print(x)

#in this code we declare variable x and it is equal to 43, then we add variable x which is 43 to 1 then the answer is 44

# %% [markdown]
# **Exercise 3**

# %%
x = 43
x = X + 1
print(x)


# The error in this code is the variable x is in a capital letter.
