# %% [markdown]
# **Exercise 1**

# %%
x = int(input('enter number'))

if x > 0 and x < 9:
    print('Above 0')
elif x > 10 and x< 19:
    print('Above 10')
elif x > 20 and x < 49:
    print('Above 20')
elif x > 50:
    print('Above 50')
else:
    print('Something else')
# Out:
# enter number16
# Above 10

# %% [markdown]
# **Exercise 2**

# %%
hours = float(input('Enter your Hours : '))
rate = float(input('Enter your Hours : '))
pay = hours*rate
if hours > 40:
  ot= hours -40
  nrate = ot*(rate*1.5)
  npay = 40*rate + nrate
  print('Pay: ',npay)
else :
  print('Pay: ',pay)
# Out:
# Enter your Hours : 45
# Enter your Hours : 10
# Pay:  475.0

# %% [markdown]
# **Challenge**

# %%
grade = float(input('Enter Grade: '))

if grade >= 0 and grade <=74:
       print('Print yout grade is 3.0')
elif grade >74 and grade <=77:
       print('Print yout grade is 2.5')
elif grade > 77 and grade <=81:
       print('Print yout grade is 2.25')
elif grade > 81 and grade <85:
       print('Print yout grade is 2.0')
elif grade >= 85 and grade <=89:
       print('Print yout grade is 1.75')
elif grade > 89 and grade <=93:
       print('Print yout grade is 1.5')
elif grade > 93 and grade <=97:
       print('Print yout grade is 1.25')
elif grade > 97 and grade <=100:
       print('Print yout grade is 1.0')

else:
  print('Invalid inputed grades')
# Out:
# Enter Grade: 92
# Print yout grade is 1.5
