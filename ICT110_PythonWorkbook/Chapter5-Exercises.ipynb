# %% [markdown]
# **Exercise 1**

# %%
a = 2
b = 2.0
c = a
a is b #using (is) is use to declare a and b is the same.
a == b #(==) is assigning the value of a to b.

# %% [markdown]
# **Challenge 1**

# %%
total_sum = 0
count = 0
numbers = []

while True:
    user_input = input("Enter a number: ")

    if user_input.lower() == 'done':
        break

    try:
        num = float(user_input)
        total_sum += num
        count += 1
        numbers.append(num)
    except ValueError:
        print("Invalid input")
        continue

if count > 0:
    average = total_sum / count
else:
    average = 0

print(f"Total: {total_sum} Count:{count} Average: {average}")
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: 7
# Enter a number: done
# Total: 16.0 Count:3 Average: 5.333333333333333

# %% [markdown]
# **Challenge 2**

# %%
numbers = []

while True:
    user_input = input("Enter a number : ")

    if user_input.lower() == 'done':
        break

    try:
        num = float(user_input)
        numbers.append(num)
    except ValueError:
        print("Invalid input")
        continue

if len(numbers) == 0:
    print("No numbers were entered.")
else:
    maximum = max(numbers)
    minimum = min(numbers)

    print(f"Maximum: {maximum}")
    print(f"Minimum: {minimum}")
# Out:
# Enter a number : 5
# Enter a number : 5
# Enter a number : done
# Maximum: 5.0
# Minimum: 5.0
