# %% [markdown]
# **Exercise 1**

# %% [markdown]
# What are the constants in the math module?
# ```
# # math.pi
# ```
# ```
# # math.e
# ```
# ```
# # math.inf
# ```
# ```
# # math.nan
# ```

# %% [markdown]
# What's does math.exp do? What about math.pow?

# %%
import math
print(math.exp(10))
print(math)

# %% [markdown]
# How do you calculate logarithms? Logarithms base 10? Natural Logarithms?

# %%
import math

print(math.log(10))

# %% [markdown]
# **Exercise 2**
#
# Create your own module. Place variables and functions inside it. Import your module and use the variabls and functions you've created in the module. Try to add docstrings for the module and the functions

# %%
"""
A module for basic mathematical operations.
"""

import math

PI = math.pi

def add(a, b):
    """
    Adds two numbers together.

    Parameters:
        a (int or float): The first number.
        b (int or float): The second number.

    Returns:
        int or float: The sum of a and b.
    """
    return a + b

def subtract(a, b):
    """
    Subtracts one number from another.

    Parameters:
        a (int or float): The number to subtract from.
        b (int or float): The number to subtract.

    Returns:
        int or float: The result of subtracting b from a.
    """
    return a - b

def multiply(a, b):
    """
    Multiplies two numbers together.

    Parameters:
        a (int or float): The first number.
        b (int or float): The second number.

    Returns:
        int or float: The product of a and b.
    """
    return a * b

def divide(a, b):
    """
    Divides one number by another.

    Parameters:
        a (int or float): The number to be divided.
        b (int or float): The divisor (cannot be zero).

    Returns:
        int or float: The result of dividing a by b.
    Raises:
        ValueError: If b is zero.
    """
    if b == 0:
        raise ValueError("Division by zero is not allowed")
    return a / b

# %%
import math_operations

print("PI:", math_operations.PI)
print("4 + 3 =", math_operations.add(4, 3))
print("7 - 5 =", math_operations.subtract(7, 5))
print("2 * 6 =", math_operations.multiply(2, 6))
print("10 / 2 =", math_operations.divide(10, 2))
